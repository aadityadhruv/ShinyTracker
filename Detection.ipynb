# %%
import numpy as np
import pandas as pd
import cv2 as cv
import cv2
import matplotlib.pyplot as plt
import time

# %%
def callback():
    x = 0

# %%
#code detects the bounding box well, and will draw top 3 approximated boxes for the top 3 contours
t_end = time.time() + 5
points = []
cap = cv.VideoCapture('http://192.168.1.8:8080/video')
num_con = 2
cv2.namedWindow("frame")

while(time.time() < t_end):
    #Read frames and convert to gray
    ret, frame = cap.read()
    gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
    
    #preprocess gaussian blur and thresholding for canny
    blur = cv.GaussianBlur(gray,(5,5),0)
    ret,thresh1 = cv2.threshold(blur,127,255,cv2.THRESH_TRUNC)
    
    #Canny using custom min/max values
    l = 100
    u = 180
    canny = cv.Canny(thresh1, l, u)
    
    #Get contrours from canny, and obtain best contours by area
    contours, hierarchy = cv2.findContours(canny, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    sort = sorted(contours, key=lambda x : cv2.contourArea(x), reverse=True)
    good_features = sort[:num_con]
    
    
    #Plot the min bounding box based on the contours
    for cnt in good_features:
        rect = cv2.minAreaRect(cnt)
        box = cv2.boxPoints(rect)
        box = np.int0(box)
        points.append(box)
        im = cv2.drawContours(frame,[box],0,(0,0,255),2)
    
    #Show the frame
    cv.imshow('frame',frame)
    cv.resizeWindow('frame', 800, 600)
    
    #Exit condition
    if cv.waitKey(1) & 0xFF == ord('q'):
        #Destroy windows on release
        cap.release()
        cv.destroyAllWindows()
cv.destroyAllWindows()

# %%
arr_points = np.array(points)

# %%
arr_points
# Out:
# array([[[603, 364],
#         [204, 364],
#         [204,  70],
#         [603,  70]],
#
#        [[747, 315],
#         [733, 314],
#         [735, 285],
#         [748, 286]],
#
#        [[753,  52],
#         [750,  37],
#         [798,  29],
#         [801,  45]],
#
#        ...,
#
#        [[ 51, 490],
#         [ 43, 481],
#         [ 60, 467],
#         [ 67, 477]],
#
#        [[605, 368],
#         [214, 365],
#         [216,  77],
#         [607,  80]],
#
#        [[751, 319],
#         [737, 318],
#         [739, 290],
#         [752, 291]]], dtype=int64)

# %%
median_list = []

# %%
for i in range(4):
    x = arr_points[:,i:i+1,0:1]
    y = arr_points[:,i:i+1,1:2]
    xt = np.resize(x, (248))
    yt = np.resize(y, (248))
    print(x)
    xm = xt.median()
    ym = yt.median()
    median_list.append([xm,ym])
# Out:
# [[[603]]
#
#  [[747]]
#
#  [[753]]
#
#  [[747]]
#
#  [[746]]
#
#  [[ 33]]
#
#  [[746]]
#
#  [[241]]
#
#  [[789]]
#
#  [[759]]
#
#  [[599]]
#
#  [[746]]
#
#  [[743]]
#
#  [[739]]
#
#  [[596]]
#
#  [[799]]
#
#  [[ 29]]
#
#  [[662]]
#
#  [[595]]
#
#  [[739]]
#
#  [[593]]
#
#  [[594]]
#
#  [[739]]
#
#  [[592]]
#
#  [[739]]
#
#  [[592]]
#
#  [[739]]
#
#  [[743]]
#
#  [[ 34]]
#
#  [[745]]
#
#  [[739]]
#
#  [[ 37]]
#
#  [[688]]
#
#  [[741]]
#
#  [[ 37]]
#
#  [[596]]
#
#  [[743]]
#
#  [[748]]
#
#  [[742]]
#
#  [[ 41]]
#
#  [[240]]
#
#  [[744]]
#
#  [[ 42]]
#
#  [[597]]
#
#  [[743]]
#
#  [[731]]
#
#  [[ 43]]
#
#  [[598]]
#
#  [[745]]
#
#  [[ 45]]
#
#  [[244]]
#
#  [[746]]
#
#  [[ 45]]
#
#  [[599]]
#
#  [[750]]
#
#  [[600]]
#
#  [[746]]
#
#  [[600]]
#
#  [[750]]
#
#  [[601]]
#
#  [[748]]
#
#  [[601]]
#
#  [[747]]
#
#  [[602]]
#
#  [[749]]
#
#  [[748]]
#
#  [[ 50]]
#
#  [[750]]
#
#  [[ 50]]
#
#  [[603]]
#
#  [[750]]
#
#  [[603]]
#
#  [[ 50]]
#
#  [[604]]
#
#  [[751]]
#
#  [[604]]
#
#  [[751]]
#
#  [[751]]
#
#  [[ 50]]
#
#  [[604]]
#
#  [[ 50]]
#
#  [[604]]
#
#  [[ 52]]
#
#  [[604]]
#
#  [[750]]
#
#  [[604]]
#
#  [[750]]
#
#  [[750]]
#
#  [[252]]
#
#  [[604]]
#
#  [[ 52]]
#
#  [[752]]
#
#  [[ 51]]
#
#  [[752]]
#
#  [[ 51]]
#
#  [[604]]
#
#  [[754]]
#
#  [[604]]
#
#  [[751]]
#
#  [[752]]
#
#  [[252]]
#
#  [[752]]
#
#  [[ 51]]
#
#  [[604]]
#
#  [[752]]
#
#  [[605]]
#
#  [[752]]
#
#  [[752]]
#
#  [[252]]
#
#  [[751]]
#
#  [[ 52]]
#
#  [[751]]
#
#  [[ 51]]
#
#  [[605]]
#
#  [[751]]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-de4144dfc46a> in <module>
#       5     yt = np.resize(y, (248))
#       6     print(x)
# ----> 7     xm = xt.median()
#       8     ym = yt.median()
#       9     median_list.append([xm,ym])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'median'

# %%
# creating a list of index names 
index_values = ['first', 'second', 'third', 
                'fourth', 'fifth', 'sixth', 'seventh'] 
   
# creating a list of column names 
column_values = ['number', 'squares', 'cubes']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-5850cd53daf7> in <module>
# ----> 1 arr_points.median()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'median'

# %%
#Steps to do
points = sorted(points)
mid = len(test_list) // 2
res = (points[mid] + points[~mid]) / 2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-27a65a18cfe9> in <module>
#       1 #Steps to do
# ----> 2 points = sorted(points)
#       3 mid = len(test_list) // 2
#       4 res = (points[mid] + points[~mid]) / 2
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
